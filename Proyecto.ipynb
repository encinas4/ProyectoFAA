# %% [markdown]
# ### Proyecto Fundamentos del Aprendizaje Automático

# %% [markdown]
# #### 1. Obtenemos las Imagenes del conjunto de datos

# %%
from tests import test_imagen, test_celdas

test_imagen()

celdas, clases = test_celdas()

# %% [markdown]
# #### 2. Obtener un conjunto de datos para trabajar a partir de las celdas

# %%
from tests import test_letritas, test_letritas_recortadas

letritas = test_letritas(celdas, clases)
letritasRecortadas = test_letritas_recortadas(letritas)
# Out:
# Ejemplo de letritas guardadas
# Ejemplo de letritas recortadas

# %% [markdown]
# #### 3. Obtener los Conjunto de Datos

# %%
from tests import test_datos

test_datos(letritas, letritasRecortadas)
# Out:
# Matriz de datos obtenida:
# [[140.          96.           0.68571429 ...   0.97441176   0.93764706
#     0.        ]
#  [147.          82.           0.55782313 ...   0.93911765   0.98323529
#     1.        ]
#  [121.         108.           0.89256198 ...   1.           0.83823529
#     2.        ]
#  ...
#  [127.         114.           0.8976378  ...   0.70676471   0.98647059
#     7.        ]
#  [144.         123.           0.85416667 ...   0.98941176   0.80911765
#     8.        ]
#  [100.         108.           1.08       ...   0.84         0.97323529
#     9.        ]]

# %% [markdown]
# ### 4. Clasificación

# %%
from clasificadores import clasificaNaiveBayes, clasificaKNN, clasificaRegresionLogistica, clasificaRandomForest, clasificaRedNeuronal, clasificaArbolDecision
from generarDatos import generacionDatos
from letrita import guardaLetritas, recortarLetritas
from generarCeldas import extrae_celdas, parametros_por_defecto

divisionVC = 10
#1. conseguimos las celdas
nombres_imagenes, \
alto,             \
ancho,            \
clases           = parametros_por_defecto()

celdas = extrae_celdas(nombres_imagenes, alto, ancho)
    
# 2. creamos las letritas
letritas = guardaLetritas(celdas, clases)

#3. recortamos las letritas
letritasRecortadas = recortarLetritas(letritas)

# %% [markdown]
# #### Atributos: Alto-Ancho

# %%
datos = generacionDatos(letritas, letritasRecortadas, [True, True, False, False, False, False, False]) #Alto, Ancho, Relacion, Pixeles, CortesH, CortesV, Rejilla

print("Media de aciertos de Naive Bayes")
print(clasificaNaiveBayes(datos, divisionVC))
print("Media de aciertos de KNN con k = 5")
print(clasificaKNN(datos, 5, divisionVC))
print("Media de aciertos de Regresión Logística con nEpocas = 1000")
print(clasificaRegresionLogistica(datos, 750, divisionVC))
print("Media de aciertos de RandomForest")
print(clasificaRandomForest(datos, 500, 2, 1,divisionVC))
print("Media de aciertos de Red Neuronal")
print(clasificaRedNeuronal(datos, 750, divisionVC))
print("Media de aciertos de Arbol de decision")
print(clasificaArbolDecision(datos, divisionVC))
# Out:
# Media de aciertos de Naive Bayes
# 0.17626373626373626
# Media de aciertos de KNN con k = 5
# 0.14489010989010992
# Media de aciertos de Regresión Logística con nEpocas = 1000
# 0.16285714285714287
# Media de aciertos de RandomForest
# 0.14280219780219783
# Media de aciertos de Red Neuronal
# 0.1584065934065934
# Media de aciertos de Arbol de decision
# 0.14725274725274726

# %% [markdown]
# #### Atributos: Relacion-Pixeles

# %%
datos = generacionDatos(letritas, letritasRecortadas, [False, False, True, True, False, False, False]) #Alto, Ancho, Relacion, Pixeles, CortesH, CortesV, Rejilla

print("Media de aciertos de Naive Bayes")
print(clasificaNaiveBayes(datos, divisionVC))
print("Media de aciertos de KNN con k = 5")
print(clasificaKNN(datos, 5, divisionVC))
print("Media de aciertos de Regresión Logística con nEpocas = 1000")
print(clasificaRegresionLogistica(datos, 750, divisionVC))
print("Media de aciertos de RandomForest")
print(clasificaRandomForest(datos, 500, 2, 1,divisionVC))
print("Media de aciertos de Red Neuronal")
print(clasificaRedNeuronal(datos, 750, divisionVC))
print("Media de aciertos de Arbol de decision")
print(clasificaArbolDecision(datos, divisionVC))
# Out:
# Media de aciertos de Naive Bayes
# 0.24032967032967031
# Media de aciertos de KNN con k = 5
# 0.1858791208791209
# Media de aciertos de Regresión Logística con nEpocas = 1000
# 0.21456043956043955
# Media de aciertos de RandomForest
# 0.1758241758241758
# Media de aciertos de Red Neuronal
# 0.21071428571428572
# Media de aciertos de Arbol de decision
# 0.1701648351648352

# %% [markdown]
# #### Atributos: Alto-Ancho-Relacion-Pixeles

# %%
datos = generacionDatos(letritas, letritasRecortadas, [True, True, True, True, False, False, False]) #Alto, Ancho, Relacion, Pixeles, CortesH, CortesV, Rejilla

print("Media de aciertos de Naive Bayes")
print(clasificaNaiveBayes(datos, divisionVC))
print("Media de aciertos de KNN con k = 5")
print(clasificaKNN(datos, 5, divisionVC))
print("Media de aciertos de Regresión Logística con nEpocas = 1000")
print(clasificaRegresionLogistica(datos, 750, divisionVC))
print("Media de aciertos de RandomForest")
print(clasificaRandomForest(datos, 500, 2, 1,divisionVC))
print("Media de aciertos de Red Neuronal")
print(clasificaRedNeuronal(datos, 750, divisionVC))
print("Media de aciertos de Arbol de decision")
print(clasificaArbolDecision(datos, divisionVC))
# Out:
# Media de aciertos de Naive Bayes
# 0.25049450549450547
# Media de aciertos de KNN con k = 5
# 0.14664835164835166
# Media de aciertos de Regresión Logística con nEpocas = 1000
# 0.22725274725274724
# Media de aciertos de RandomForest
# 0.21076923076923076
# Media de aciertos de Red Neuronal
# 0.15005494505494504
# Media de aciertos de Arbol de decision
# 0.17379120879120882

# %% [markdown]
# #### Atributos: Cortes Horizontales-Cortes Verticales

# %%
datos = generacionDatos(letritas, letritasRecortadas, [False, False, False, False, True, True, False], 20, 20) #Alto, Ancho, Relacion, Pixeles, CortesH, CortesV, Rejilla

print("Media de aciertos de Naive Bayes")
print(clasificaNaiveBayes(datos, divisionVC))
print("Media de aciertos de KNN con k = 5")
print(clasificaKNN(datos, 5, divisionVC))
print("Media de aciertos de Regresión Logística con nEpocas = 1000")
print(clasificaRegresionLogistica(datos, 750, divisionVC))
print("Media de aciertos de RandomForest")
print(clasificaRandomForest(datos, 500, 2, 1,divisionVC))
print("Media de aciertos de Red Neuronal")
print(clasificaRedNeuronal(datos, 750, divisionVC))
print("Media de aciertos de Arbol de decision")
print(clasificaArbolDecision(datos, divisionVC))
# Out:
# Media de aciertos de Naive Bayes
# 0.5118681318681318
# Media de aciertos de KNN con k = 5
# 0.7543956043956044
# Media de aciertos de Regresión Logística con nEpocas = 1000
# 0.6576923076923077
# Media de aciertos de RandomForest
# 0.8133516483516484
# Media de aciertos de Red Neuronal
# /home/david/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (750) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 0.7123076923076923
# Media de aciertos de Arbol de decision
# 0.6539010989010988

# %% [markdown]
# #### Atributos: Rejilla

# %%
datos = generacionDatos(letritas, letritasRecortadas, [False, False, False, False, False, False, True], 0, 0, 15) #Alto, Ancho, Relacion, Pixeles, CortesH, CortesV, Rejilla

print("Media de aciertos de Naive Bayes")
print(clasificaNaiveBayes(datos, divisionVC))
print("Media de aciertos de KNN con k = 5")
print(clasificaKNN(datos, 5, divisionVC))
print("Media de aciertos de Regresión Logística con nEpocas = 1000")
print(clasificaRegresionLogistica(datos, 750, divisionVC))
print("Media de aciertos de RandomForest")
print(clasificaRandomForest(datos, 500, 2, 1,divisionVC))
print("Media de aciertos de Red Neuronal")
print(clasificaRedNeuronal(datos, 750, divisionVC))
print("Media de aciertos de Arbol de decision")
print(clasificaArbolDecision(datos, divisionVC))
# Out:
# Media de aciertos de Naive Bayes
# 0.4191758241758242
# Media de aciertos de KNN con k = 5
# 0.8582967032967034
# Media de aciertos de Regresión Logística con nEpocas = 1000
# 0.7721978021978021
# Media de aciertos de RandomForest
# 0.8832967032967034
# Media de aciertos de Red Neuronal
# 0.8197252747252748
# Media de aciertos de Arbol de decision
# 0.644065934065934

# %% [markdown]
# #### Atributos: Cortes Horizontales-Cortes Verticales-Rejilla

# %%
datos = generacionDatos(letritas, letritasRecortadas, [False, False, False, False, True, True, True], 20, 20, 15) #Alto, Ancho, Relacion, Pixeles, CortesH, CortesV, Rejilla

print("Media de aciertos de Naive Bayes")
print(clasificaNaiveBayes(datos, divisionVC))
print("Media de aciertos de KNN con k = 5")
print(clasificaKNN(datos, 5, divisionVC))
print("Media de aciertos de Regresión Logística con nEpocas = 1000")
print(clasificaRegresionLogistica(datos, 750, divisionVC))
print("Media de aciertos de RandomForest")
print(clasificaRandomForest(datos, 500, 2, 1,divisionVC))
print("Media de aciertos de Red Neuronal")
print(clasificaRedNeuronal(datos, 750, divisionVC))
print("Media de aciertos de Arbol de decision")
print(clasificaArbolDecision(datos, divisionVC))
# Out:
# Media de aciertos de Naive Bayes
# 0.4775824175824176
# Media de aciertos de KNN con k = 5
# 0.8790659340659343
# Media de aciertos de Regresión Logística con nEpocas = 1000
# 0.8787362637362637
# Media de aciertos de RandomForest
# 0.9232417582417582
# Media de aciertos de Red Neuronal
# 0.8835714285714286
# Media de aciertos de Arbol de decision
# 0.7335714285714285

# %% [markdown]
# #### Atributos: Alto-Ancho-Relacion-Pixeles-Cortes Horizontales-Cortes Verticales

# %%
datos = generacionDatos(letritas, letritasRecortadas, [True, True, True, True, True, True, False], 20, 20) #Alto, Ancho, Relacion, Pixeles, CortesH, CortesV, Rejilla

print("Media de aciertos de Naive Bayes")
print(clasificaNaiveBayes(datos, divisionVC))
print("Media de aciertos de KNN con k = 5")
print(clasificaKNN(datos, 5, divisionVC))
print("Media de aciertos de Regresión Logística con nEpocas = 1000")
print(clasificaRegresionLogistica(datos, 750, divisionVC))
print("Media de aciertos de RandomForest")
print(clasificaRandomForest(datos, 500, 2, 1,divisionVC))
print("Media de aciertos de Red Neuronal")
print(clasificaRedNeuronal(datos, 750, divisionVC))
print("Media de aciertos de Arbol de decision")
print(clasificaArbolDecision(datos, divisionVC))
# Out:
# Media de aciertos de Naive Bayes
# 0.6
# Media de aciertos de KNN con k = 5
# 0.5185164835164835
# Media de aciertos de Regresión Logística con nEpocas = 1000
# 0.6974725274725275
# Media de aciertos de RandomForest
# 0.828076923076923
# Media de aciertos de Red Neuronal
# 0.7
# Media de aciertos de Arbol de decision
# 0.6492857142857142

# %% [markdown]
# #### Atributos: Alto-Ancho-Relacion-Pixeles-Cortes Horizontales-Cortes Verticales-Rejilla

# %%
datos = generacionDatos(letritas, letritasRecortadas, [True, True, True, True, True, True, True], 20, 20, 15) #Alto, Ancho, Relacion, Pixeles, CortesH, CortesV, Rejilla

print("Media de aciertos de Naive Bayes")
print(clasificaNaiveBayes(datos, divisionVC))
print("Media de aciertos de KNN con k = 5")
print(clasificaKNN(datos, 5, divisionVC))
print("Media de aciertos de Regresión Logística con nEpocas = 1000")
print(clasificaRegresionLogistica(datos, 750, divisionVC))
print("Media de aciertos de RandomForest")
print(clasificaRandomForest(datos, 500, 2, 1,divisionVC))
print("Media de aciertos de Red Neuronal")
print(clasificaRedNeuronal(datos, 750, divisionVC))
print("Media de aciertos de Arbol de decision")
print(clasificaArbolDecision(datos, divisionVC))
# Out:
# Media de aciertos de Naive Bayes
# 0.4999450549450549
# Media de aciertos de KNN con k = 5
# 0.8036813186813188
# Media de aciertos de Regresión Logística con nEpocas = 1000
# 0.882967032967033
# Media de aciertos de RandomForest
# 0.9214285714285715
# Media de aciertos de Red Neuronal
# 0.8920329670329672
# Media de aciertos de Arbol de decision
# 0.72
